# %% [markdown]
# ### Fonte: https://ckan.pbh.gov.br/en/dataset/indicadores-dos-objetivos-de-desenvolvimento-sustentavel-ods

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#df = pd.read_csv('IndicadoresODS.csv', sep=';', engine='python', encoding='latin1')
df = pd.read_excel('IDD_2023.xlsx')
display(df)
# Out:
#                                                     Ano   Código da Área  \
# 0                                                  2023           6002.0
# 1                                                  2023             17.0
# 2                                                  2023           5710.0
# 3                                                  2023             23.0
# 4                                                  2023             19.0
# ...                                                 ...              ...
# 9810                                               2023           5902.0
# 9811                                               2023             19.0
# 9812                                                NaN              NaN
# 9813  * Nome e Sigla da IES atualizados na data da d...              NaN
# 9814  ** Para os cursos na modalidade a distância, o...              NaN
#
#             Área de Avaliação   Código da IES  \
# ...
